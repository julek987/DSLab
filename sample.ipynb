# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("data/gun_violence_data.xlsx")

# %%
df.head()
# Out:
#    incident_id       date           state city_or_county  \
# 0       461105 2013-01-01    Pennsylvania     Mckeesport
# 1       460726 2013-01-01      California      Hawthorne
# 2       478855 2013-01-01            Ohio         Lorain
# 3       478925 2013-01-05        Colorado         Aurora
# 4       478959 2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  latitude  \
# 0  1506 Versailles Avenue and Coursin Street         0          4   40.3467
# 1               13500 block of Cerise Avenue         1          3   33.9090
# 2                      1776 East 28th Street         1          3   41.4455
# 3           16000 block of East Ithaca Place         4          0   39.6518
# 4                  307 Mourning Dove Terrace         2          2   36.1140
#
#    longitude
# 0   -79.8559
# 1  -118.3330
# 2   -82.1377
# 3  -104.8020
# 4   -79.9569

# %%
df_drop = df.drop(columns=["date", "address", "latitude", "longitude", "city_or_county", "incident_id"])

# %%
df_drop["injured_or_killed"] = df_drop["n_injured"] + df_drop["n_killed"]

# %%
df_drop.groupby("state").sum()
# Out:
#                       n_killed  n_injured  injured_or_killed
# state
# Alabama                   1880       2998               4878
# Alaska                     267        325                592
# Arizona                   1094       1096               2190
# Arkansas                   773       1347               2120
# California                5562       7644              13206
# Colorado                   796       1133               1929
# Connecticut                341       1258               1599
# Delaware                   217        853               1070
# District of Columbia       459       1415               1874
# Florida                   3909       7072              10981
# Georgia                   2456       4056               6512
# Hawaii                      63         85                148
# Idaho                      166        149                315
# Illinois                  3409      13514              16923
# Indiana                   1608       2956               4564
# Iowa                       273        821               1094
# Kansas                     542        931               1473
# Kentucky                  1066       1894               2960
# Louisiana                 2179       4398               6577
# Maine                      112        132                244
# Maryland                  1691       3167               4858
# Massachusetts              472       1701               2173
# Michigan                  1588       2990               4578
# Minnesota                  461        916               1377
# Mississippi               1176       1883               3059
# Missouri                  2136       3585               5721
# Montana                    154        136                290
# Nebraska                   225        674                899
# Nevada                     799        951               1750
# New Hampshire               88        144                232
# New Jersey                1168       2540               3708
# New Mexico                 495        543               1038
# New York                  1705       5059               6764
# North Carolina            2225       4629               6854
# North Dakota                69        130                199
# Ohio                      2508       5703               8211
# Oklahoma                   941       1550               2491
# Oregon                     446        694               1140
# Pennsylvania              2395       5056               7451
# Rhode Island                63        346                409
# South Carolina            1610       3084               4694
# South Dakota                90        114                204
# Tennessee                 1824       4478               6302
# Texas                     5046       6106              11152
# Utah                       282        402                684
# Vermont                     57         73                130
# Virginia                  1459       3566               5025
# Washington                 853       1287               2140
# West Virginia              335        649                984
# Wisconsin                  862       2117               2979
# Wyoming                     73         52                125

# %%
grouped_df = df_drop.groupby("state").sum().reset_index()

# %%
# Normalize the values for color mapping
norm = plt.Normalize(grouped_df['injured_or_killed'].min(), grouped_df['injured_or_killed'].max())
cmap = plt.get_cmap('RdYlGn_r')  # Red to Green colormap

# Create a color array based on the 'injured_or_killed' values
colors = cmap(norm(grouped_df['injured_or_killed']))

# %%
# Plotting
plt.figure(figsize=(12, 6))  # Set figure size
bars = plt.bar(grouped_df['state'], grouped_df['injured_or_killed'], color=colors)

plt.xlabel('State')
plt.ylabel('Injured or Killed')
plt.title('Injured or Killed by State (Green = Less, Red = More)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels
plt.tight_layout()  # Adjust layout to fit all elements

# Create a colorbar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # Only needed for older versions of matplotlib
cbar = plt.colorbar(sm, ax=plt.gca(), orientation='vertical')
cbar.set_label('Injured or Killed')

plt.show()

# %%
# Normalize the values for color mapping
norm = plt.Normalize(grouped_df['n_killed'].min(), grouped_df['n_killed'].max())
cmap = plt.get_cmap('RdYlGn_r')  # Red to Green colormap

# Create a color array based on the 'injured_or_killed' values
colors = cmap(norm(grouped_df['n_killed']))

# %%
# Plotting
plt.figure(figsize=(12, 6))  # Set figure size
bars = plt.bar(grouped_df['state'], grouped_df['n_killed'], color=colors)

plt.xlabel('State')
plt.ylabel('Killed')
plt.title('Killed by State (Green = Less, Red = More)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels
plt.tight_layout()  # Adjust layout to fit all elements

# Create a colorbar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # Only needed for older versions of matplotlib
cbar = plt.colorbar(sm, ax=plt.gca(), orientation='vertical')
cbar.set_label('Killed')

plt.show()

# %%
# Normalize the values for color mapping
norm = plt.Normalize(grouped_df['n_injured'].min(), grouped_df['n_injured'].max())
cmap = plt.get_cmap('RdYlGn_r')  # Red to Green colormap

# Create a color array based on the 'injured_or_killed' values
colors = cmap(norm(grouped_df['n_injured']))

# %%
# Plotting
plt.figure(figsize=(12, 6))  # Set figure size
bars = plt.bar(grouped_df['state'], grouped_df['n_injured'], color=colors)

plt.xlabel('State')
plt.ylabel('Injured')
plt.title('Injured by State (Green = Less, Red = More)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels
plt.tight_layout()  # Adjust layout to fit all elements

# Create a colorbar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # Only needed for older versions of matplotlib
cbar = plt.colorbar(sm, ax=plt.gca(), orientation='vertical')
cbar.set_label('Injured')

plt.show()

# %%
us_pop = pd.read_excel("data/us_population.xlsx")

# %%
us_pop.head()
# Out:
#   table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0  Table 1. Annual Estimates of the Resident Popu...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                      United States
# 4                                          Northeast
#
#             Unnamed: 1      Unnamed: 2                          Unnamed: 3  \
# 0                  NaN             NaN                                 NaN
# 1  2010-04-01 00:00:00             NaN  Population Estimate (as of July 1)
# 2               Census  Estimates Base                                2010
# 3            308745538       308758105                           309321666
# 4             55317240        55318443                            55380134
#
#     Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       2011.0       2012.0       2013.0       2014.0       2015.0
# 3  311556874.0  313830990.0  315993715.0  318301008.0  320635163.0
# 4   55604223.0   55775216.0   55901806.0   56006011.0   56034684.0
#
#     Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2       2016.0       2017.0       2018.0       2019.0
# 3  322941311.0  324985539.0  326687501.0  328239523.0
# 4   56042330.0   56059240.0   56046620.0   55982803.0

# %%
us_pop_drop = us_pop.drop(columns=["Unnamed: 1", "Unnamed: 2", "Unnamed: 3", "Unnamed: 4", "Unnamed: 5", "Unnamed: 7", "Unnamed: 8", "Unnamed: 9", "Unnamed: 10", "Unnamed: 11", "Unnamed: 12"])

# %%
us_pop_drop.head()
# Out:
#   table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0  Table 1. Annual Estimates of the Resident Popu...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                      United States
# 4                                          Northeast
#
#     Unnamed: 6
# 0          NaN
# 1          NaN
# 2       2013.0
# 3  315993715.0
# 4   55901806.0

# %%
n = 8
us_pop_drop = us_pop_drop[n:]
us_pop_drop.head()
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 8                                            .Alabama
# 9                                             .Alaska
# 10                                           .Arizona
# 11                                          .Arkansas
# 12                                        .California
#
#     Unnamed: 6
# 8    4830081.0
# 9     737068.0
# 10   6632764.0
# 11   2959400.0
# 12  38260787.0

# %%
# Rename specific columns
us_pop_drop.rename(columns={'table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)': 'State', 
                   'Unnamed: 6': 'Population'}, inplace=True)

# %%
us_pop_drop.head()
# Out:
#           State  Population
# 8      .Alabama   4830081.0
# 9       .Alaska    737068.0
# 10     .Arizona   6632764.0
# 11    .Arkansas   2959400.0
# 12  .California  38260787.0

# %%
# Remove leading dots from the 'state' column
us_pop_drop['State'] = us_pop_drop['State'].str.lstrip('.')

# %%
us_pop_drop.head()
# Out:
#          State  Population
# 8      Alabama   4830081.0
# 9       Alaska    737068.0
# 10     Arizona   6632764.0
# 11    Arkansas   2959400.0
# 12  California  38260787.0

# %%
# Merge the gun violence data with the population data
# Rename the 'state' column in grouped_df before merging
grouped_df.rename(columns={'state': 'State'}, inplace=True)

# Now merge
merged_df = pd.merge(
    grouped_df,   # Will now have 'State' instead of 'state'
    us_pop_drop,  # Contains 'State'
    on='State',   # Merge on the renamed column
    how='inner'
)

# Display the merged DataFrame
merged_df.head()
# Out:
#         State  n_killed  n_injured  injured_or_killed  Population
# 0     Alabama      1880       2998               4878   4830081.0
# 1      Alaska       267        325                592    737068.0
# 2     Arizona      1094       1096               2190   6632764.0
# 3    Arkansas       773       1347               2120   2959400.0
# 4  California      5562       7644              13206  38260787.0

# %%
merged_df["injured_or_killed_per_1000"] = merged_df["injured_or_killed"] / merged_df["Population"] * 1000

# %%
merged_df.head()
# Out:
#         State  n_killed  n_injured  injured_or_killed  Population  \
# 0     Alabama      1880       2998               4878   4830081.0
# 1      Alaska       267        325                592    737068.0
# 2     Arizona      1094       1096               2190   6632764.0
# 3    Arkansas       773       1347               2120   2959400.0
# 4  California      5562       7644              13206  38260787.0
#
#    injured_or_killed_per_1000
# 0                    1.009921
# 1                    0.803182
# 2                    0.330179
# 3                    0.716361
# 4                    0.345158

# %%
merged_df.to_excel("data/merged_data.xlsx", index=False)
