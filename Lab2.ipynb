# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import matplotlib as mpl
import folium
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("data/Lab2/us_contagious_diseases.csv")

# %%
df_drop = df.drop(columns=['Unnamed: 0', 'year', 'weeks_reporting', 'population'])

# %%
df_drop.head(30)
# Out:
#         disease    state  count
# 0   Hepatitis A  Alabama    321
# 1   Hepatitis A  Alabama    291
# 2   Hepatitis A  Alabama    314
# 3   Hepatitis A  Alabama    380
# 4   Hepatitis A  Alabama    413
# 5   Hepatitis A  Alabama    378
# 6   Hepatitis A  Alabama    342
# 7   Hepatitis A  Alabama    467
# 8   Hepatitis A  Alabama    244
# 9   Hepatitis A  Alabama    286
# 10  Hepatitis A  Alabama    220
# 11  Hepatitis A  Alabama    206
# 12  Hepatitis A  Alabama    203
# 13  Hepatitis A  Alabama    257
# 14  Hepatitis A  Alabama    200
# 15  Hepatitis A  Alabama    138
# 16  Hepatitis A  Alabama    128
# 17  Hepatitis A  Alabama    178
# 18  Hepatitis A  Alabama    115
# 19  Hepatitis A  Alabama     37
# 20  Hepatitis A  Alabama     51
# 21  Hepatitis A  Alabama     81
# 22  Hepatitis A  Alabama     13
# 23  Hepatitis A  Alabama     56
# 24  Hepatitis A  Alabama     86
# 25  Hepatitis A  Alabama     39
# 26  Hepatitis A  Alabama     35
# 27  Hepatitis A  Alabama     40
# ...

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16065 entries, 0 to 16064
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   disease  16065 non-null  object
#  1   state    16065 non-null  object
#  2   count    16065 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 376.7+ KB

# %%
aggregated_df = df_drop.groupby(['state', 'disease'], as_index=False)['count'].sum()

# %%
aggregated_df.head(55)
# Out:
#           state      disease    count
# 0       Alabama  Hepatitis A     6298
# 1       Alabama      Measles   209582
# 2       Alabama        Mumps     6315
# 3       Alabama    Pertussis    25529
# 4       Alabama        Polio     6054
# 5       Alabama      Rubella     2051
# 6       Alabama     Smallpox     2150
# 7        Alaska  Hepatitis A     5647
# 8        Alaska      Measles    16908
# 9        Alaska        Mumps     3650
# 10       Alaska    Pertussis      991
# 11       Alaska        Polio      526
# 12       Alaska      Rubella     1414
# 13       Alaska     Smallpox        0
# 14      Arizona  Hepatitis A    31900
# 15      Arizona      Measles   160810
# 16      Arizona        Mumps     9299
# 17      Arizona    Pertussis    26417
# 18      Arizona        Polio     2988
# 19      Arizona      Rubella     6922
# 20      Arizona     Smallpox     1897
# 21     Arkansas  Hepatitis A     7494
# 22     Arkansas      Measles   134250
# 23     Arkansas        Mumps     3942
# ...
